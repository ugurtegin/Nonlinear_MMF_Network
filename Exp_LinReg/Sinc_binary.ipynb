# %% [markdown]
# <a href="https://colab.research.google.com/github/ugurtegin/Nonlinear_MMF_Network/blob/main/Exp_LinReg/Sinc_binary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
import tensorflow as tf


from tensorflow import keras
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.layers import Input, Activation, LSTM
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, AveragePooling2D 
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.utils import to_categorical, normalize

# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import scipy.io as sio
f = sio.loadmat('/content/drive/My Drive/Sinc/res_sq_flt2.mat')
inp2 = f['res_sq_flt']

#Load data
f2 = sio.loadmat('/content/drive/My Drive/Sinc/data.mat')

out = f2['y']
xx = f2['x']

# %%
#inp2 = inp / np.linalg.norm(inp)
#inp2 = inp2*1000

# %%
# demonstrate data standardization with sklearn
from sklearn.preprocessing import StandardScaler
# load data
# create scaler
scaler = StandardScaler()
# fit scaler on data
scaler.fit(inp2)
# apply transform
inp4 = scaler.transform(inp2)
# inverse transform

# %%
plt.plot(inp4[10,])
plt.show()

# %%
input_data = inp4
output_data = out

print('input_data : ', input_data.shape, input_data.dtype)
print('output_class : ', output_data.shape, output_data.dtype)
print()
# Out:
# input_data :  (3000, 484) float64
# output_class :  (3000, 1) float64

# %%
oran = 0.20
X_train, X_test, y_train, y_test = train_test_split(input_data, output_data, test_size=oran)

print('Test data : ', X_test.shape, X_test.dtype)
print('Training data : ', X_train.shape, X_train.dtype)
print()
# Out:
# Test data :  (600, 484) float64
# Training data :  (2400, 484) float64

# %%
model = Sequential()
#model.add(Dropout(0.2, ))
model.add(Dense(1, input_dim=484, activation='linear'))
#model.add(Dense(1, activation='linear'))

# %%
loss='mean_squared_error' # mean_absolute_error, cosine_proximity
metrics = ['mean_squared_error']  # network accuracy metric to be determined after each epoch, mean_absolute_error, cosine_proximity

opt1 = SGD(lr=0.001, momentum=0.9)
opt2 = Adam(lr=0.001, beta_1=0.9, beta_2=0.999)

model.compile(optimizer=opt2, loss=loss, metrics=metrics)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 485
# =================================================================
# Total params: 485
# Trainable params: 485
# Non-trainable params: 0
# _________________________________________________________________

# %%
#setting final parameters for the network and it begins to train
number_of_iterations = 50
#batch_size = 50

history=model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=number_of_iterations)
#history=model.fit(X_train, y_train, batch_size=batch_size, epochs=number_of_iterations, verbose=1, validation_data=(X_test, y_test))
#Number of iterations run: 900
# Out:
# Epoch 1/50
# 75/75 [==============================] - 0s 3ms/step - loss: 0.5775 - mean_squared_error: 0.5775 - val_loss: 0.3158 - val_mean_squared_error: 0.3158
# Epoch 2/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2763 - mean_squared_error: 0.2763 - val_loss: 0.2224 - val_mean_squared_error: 0.2224
# Epoch 3/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1951 - mean_squared_error: 0.1951 - val_loss: 0.1764 - val_mean_squared_error: 0.1764
# Epoch 4/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1532 - mean_squared_error: 0.1532 - val_loss: 0.1394 - val_mean_squared_error: 0.1394
# Epoch 5/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1240 - mean_squared_error: 0.1240 - val_loss: 0.1230 - val_mean_squared_error: 0.1230
# Epoch 6/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1007 - mean_squared_error: 0.1007 - val_loss: 0.1010 - val_mean_squared_error: 0.1010
# Epoch 7/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0866 - mean_squared_error: 0.0866 - val_loss: 0.0860 - val_mean_squared_error: 0.0860
# Epoch 8/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0730 - mean_squared_error: 0.0730 - val_loss: 0.0805 - val_mean_squared_error: 0.0805
# Epoch 9/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0634 - mean_squared_error: 0.0634 - val_loss: 0.0700 - val_mean_squared_error: 0.0700
# Epoch 10/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0566 - mean_squared_error: 0.0566 - val_loss: 0.0635 - val_mean_squared_error: 0.0635
# Epoch 11/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0502 - mean_squared_error: 0.0502 - val_loss: 0.0600 - val_mean_squared_error: 0.0600
# Epoch 12/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0475 - mean_squared_error: 0.0475 - val_loss: 0.0516 - val_mean_squared_error: 0.0516
# Epoch 13/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0412 - mean_squared_error: 0.0412 - val_loss: 0.0497 - val_mean_squared_error: 0.0497
# Epoch 14/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0391 - mean_squared_error: 0.0391 - val_loss: 0.0458 - val_mean_squared_error: 0.0458
# Epoch 15/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0339 - mean_squared_error: 0.0339 - val_loss: 0.0413 - val_mean_squared_error: 0.0413
# Epoch 16/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0315 - mean_squared_error: 0.0315 - val_loss: 0.0389 - val_mean_squared_error: 0.0389
# Epoch 17/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0301 - mean_squared_error: 0.0301 - val_loss: 0.0403 - val_mean_squared_error: 0.0403
# Epoch 18/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0288 - mean_squared_error: 0.0288 - val_loss: 0.0336 - val_mean_squared_error: 0.0336
# Epoch 19/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0262 - mean_squared_error: 0.0262 - val_loss: 0.0391 - val_mean_squared_error: 0.0391
# Epoch 20/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0251 - mean_squared_error: 0.0251 - val_loss: 0.0319 - val_mean_squared_error: 0.0319
# Epoch 21/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0242 - mean_squared_error: 0.0242 - val_loss: 0.0301 - val_mean_squared_error: 0.0301
# Epoch 22/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0290 - val_mean_squared_error: 0.0290
# Epoch 23/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0236 - mean_squared_error: 0.0236 - val_loss: 0.0306 - val_mean_squared_error: 0.0306
# Epoch 24/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0216 - mean_squared_error: 0.0216 - val_loss: 0.0284 - val_mean_squared_error: 0.0284
# Epoch 25/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0202 - mean_squared_error: 0.0202 - val_loss: 0.0261 - val_mean_squared_error: 0.0261
# Epoch 26/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0205 - mean_squared_error: 0.0205 - val_loss: 0.0264 - val_mean_squared_error: 0.0264
# Epoch 27/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0199 - mean_squared_error: 0.0199 - val_loss: 0.0268 - val_mean_squared_error: 0.0268
# Epoch 28/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0206 - mean_squared_error: 0.0206 - val_loss: 0.0282 - val_mean_squared_error: 0.0282
# Epoch 29/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# Epoch 30/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0245 - val_mean_squared_error: 0.0245
# Epoch 31/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0231 - val_mean_squared_error: 0.0231
# Epoch 32/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0187 - mean_squared_error: 0.0187 - val_loss: 0.0252 - val_mean_squared_error: 0.0252
# Epoch 33/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0265 - val_mean_squared_error: 0.0265
# Epoch 34/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# Epoch 35/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0207 - mean_squared_error: 0.0207 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 36/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0246 - val_mean_squared_error: 0.0246
# Epoch 37/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0220 - mean_squared_error: 0.0220 - val_loss: 0.0245 - val_mean_squared_error: 0.0245
# Epoch 38/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0219 - val_mean_squared_error: 0.0219
# Epoch 39/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0230 - val_mean_squared_error: 0.0230
# Epoch 40/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0227 - val_mean_squared_error: 0.0227
# Epoch 41/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0223 - val_mean_squared_error: 0.0223
# Epoch 42/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0220 - val_mean_squared_error: 0.0220
# Epoch 43/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0215 - val_mean_squared_error: 0.0215
# Epoch 44/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0251 - val_mean_squared_error: 0.0251
# Epoch 45/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0224 - val_mean_squared_error: 0.0224
# Epoch 46/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0222 - val_mean_squared_error: 0.0222
# Epoch 47/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0219 - val_mean_squared_error: 0.0219
# Epoch 48/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0294 - val_mean_squared_error: 0.0294
# Epoch 49/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0210 - val_mean_squared_error: 0.0210
# Epoch 50/50
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0223 - val_mean_squared_error: 0.0223

# %%
from google.colab import files
# summarize history for loss
ls=plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
#plt.ylim(0.02,0.4)
ls.show()
ls.savefig('/content/drive/My Drive/Sinc/loss-exp.png')
#files.download('loss-1.png')

# %%
abit = model.predict(inp4)
abit.shape
# Out:
# (3000, 1)

# %%
ls=plt.figure()
plt.plot(abit)
plt.plot(output_data)
plt.ylabel('Value')
plt.xlabel('Sample')
plt.legend(['Network Prediction', 'Ground truth'], loc='upper left')
ls.show()
ls.savefig('/content/drive/My Drive/Sinc/est-exp.png')

# %%
plt.plot(output_data)
plt.plot(abit)
ls.show()

# %%
ls=plt.figure()
plt.scatter(xx,abit)
plt.scatter(xx,np.sinc(xx))
plt.ylabel('Y')
plt.xlabel('X')
plt.legend(['Ground truth', 'Network prediction'], loc='upper left')
plt.show()
ls.savefig('/content/drive/My Drive/Sinc/sinc-exp.png')
